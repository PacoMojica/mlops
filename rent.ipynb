# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

sns.set_theme()

# %% [markdown]
# ## Load Dataset

# %%
dataset = pd.read_csv("House_Rent_Dataset.csv", low_memory=False)

# %% [markdown]
# ## Info

# %%
dataset.info()

# %%
dataset.describe().T
# Out:
#            count          mean           std     min      25%      50%  \
# BHK       4746.0      2.083860      0.832256     1.0      2.0      2.0
# Rent      4746.0  34993.451327  78106.412937  1200.0  10000.0  16000.0
# Size      4746.0    967.490729    634.202328    10.0    550.0    850.0
# Bathroom  4746.0      1.965866      0.884532     1.0      1.0      2.0
#
#               75%        max
# BHK           3.0        6.0
# Rent      33000.0  3500000.0
# Size       1200.0     8000.0
# Bathroom      2.0       10.0

# %%
dataset.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %%
msno.bar(dataset)
# Out:
# <AxesSubplot:>

# %%
dataset["Rent"].mean()
# Out:
# 34993.45132743363

# %%
fig, ax = plt.subplots()
ax.hist(dataset["Rent"])
ax.set_yscale('log')

# %%
sum(dataset["Rent"].isnull())
# Out:
# 0

# %%
sns.countplot(x="Bathroom", data=dataset)
# Out:
# <AxesSubplot:xlabel='Bathroom', ylabel='count'>

# %%
dataset["Furnishing Status"].value_counts()
# Out:
# Semi-Furnished    2251
# Unfurnished       1815
# Furnished          680
# Name: Furnishing Status, dtype: int64

# %%
sns.countplot(x="Furnishing Status", data=dataset)
# Out:
# <AxesSubplot:xlabel='Furnishing Status', ylabel='count'>

# %%
sns.countplot(x="Tenant Preferred", data=dataset)
# Out:
# <AxesSubplot:xlabel='Tenant Preferred', ylabel='count'>

# %%
sns.countplot(x="Area Type", data=dataset)
# Out:
# <AxesSubplot:xlabel='Area Type', ylabel='count'>

# %%
sns.scatterplot(
    y=dataset["Rent"], x=dataset["Size"], hue=dataset["Furnishing Status"], data=dataset
)
# Out:
# <AxesSubplot:xlabel='Size', ylabel='Rent'>

# %%
sns.histplot(x="Rent", data=dataset)
# Out:
# <AxesSubplot:xlabel='Rent', ylabel='Count'>

# %%
sns.histplot(x="Rent", data=dataset, log_scale=True)
# Out:
# <AxesSubplot:xlabel='Rent', ylabel='Count'>

# %%
sns.histplot(x="Rent", y=dataset["Furnishing Status"], data=dataset, log_scale=(True, False), cbar=True, cbar_kws=dict(shrink=.75))
# Out:
# <AxesSubplot:xlabel='Rent', ylabel='Furnishing Status'>

# %%
sns.histplot(x="Tenant Preferred", y=dataset["Furnishing Status"], data=dataset, cbar=True, cbar_kws=dict(shrink=.75))
# Out:
# <AxesSubplot:xlabel='Tenant Preferred', ylabel='Furnishing Status'>
